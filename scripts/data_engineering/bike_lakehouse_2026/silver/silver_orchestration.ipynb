# %% [markdown]
# #Orchestration Logic
# This notebook programmatically runs all Silver notebooks in sequence.
# It becomes the single entry point for the Silver layer in Databricks Jobs%md

# %%
notebooks = [
    "./crm/silver_crm_cust_info",
    "./crm/silver_crm_prd_info",
    "./crm/silver_crm_sales_details_info",
    "./erp/silver_erp_cust_az12",
    "./erp/silver_erp_loc_a101",
    "./erp/silver_erp_px_cat_g1v2"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=3600)
