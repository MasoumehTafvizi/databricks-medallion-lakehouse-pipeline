# %%
from pathlib import Path

file_path = Path.cwd() / "PX_CAT_G1V2"

if file_path.exists():
    file_path.unlink()
    print(f"Deleted: {file_path}")
else:
    print(f"File not found: {file_path}")

# %%
from pathlib import Path
import shutil

source_file = ("/Volumes/workspace/bronze/source_systems/source_erp/PX_CAT_G1V2.csv")

destination_file = Path.cwd() / "PX_CAT_G1V2.csv"

shutil.copyfile(source_file, destination_file)

print(f"Copied to: {destination_file}")
